# %%
# !pip install mysql-connector-python
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 3.8 MB/s eta 0:00:0000:0100:01
# ...
#
# [notice] A new release of pip is available: 23.3 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
# M1-Registration
# 1-->get user input(name,ph,maildid,password)
# 2-->store it in a table
# M2-->Login
# 1-->get name and password
# 2-->if its correct show succesful login
# 3-->else foreget passord option should pop up after three attempts
# M3-->reset password
# 1-->update the table with new password

# %%
import mysql.connector


mydb = mysql.connector.connect(
  host="localhost",
  user="root",
  password="",

)

print(mydb)
mycursor = mydb.cursor(buffered=True)

#mycursor.execute("CREATE DATABASE guvi12")
#create new db CREATE DATABASE mydatabase
#it willautomatically check if dbwith same name exists

# %%
mycursor.execute("SHOW DATABASES")

for x in mycursor:
  print(x)

#Show all existing db
# Out:
# ('abcd',)
# ('banana',)
# ('barath',)
# ('barath1',)
# ('dataengg',)
# ('dataks',)
# ('dt1819',)
# ('dt1819A',)
# ('dt2223',)
# ('dt26',)
# ('dw6768',)
# ('gg',)
# ('information_schema',)
# ('leo',)
# ('maggi',)
# ('mysql',)
# ('netflix',)
# ('neth',)
# ('nethaji',)
# ('nethjuu',)
# ('newguvi',)
# ('newman',)
# ('nirmal',)
# ('openh',)
# ('performance_schema',)
# ('phonepe',)
# ('phpmyadmin',)
# ('test',)
# ('world',)

# %%
mycursor.execute("USE dt2223")

#change to another db if required

# %%
#renaming the databse direct is not permitted since a lot of users arein the scene
mycursor.execute("CREATE DATABASE dt2223")

#mycursor.execute("RENAME TABLE guvi1.customers TO newguvi.customers")

#so create a new db and rename the old tables(it will get transferred)

# %%
print(f"\n nirmal")
print(r"\n nirmal")
# Out:
#  nirmal
# \n nirmal

# %%
# try:
#     a=input("enter the databse name")

#     mycursor.execute(f"CREATE DATABASE {a}")
# except:
#     print("database already created")

id=int(input())
name=input()
class1=input()
age=int(input())

mycursor.execute(f"INSERT INTO dt2223.student (ID,name,class,age) values({id},'{name}','{class1}',{age})")
mydb.commit()

# %%
print(f"INSERT INTO dt2223.student (ID,name,class,age) values({id},'{name}','{class1}',{age})")
# Out:
# INSERT INTO dt2223.student (ID,name,class,age) values(3,'nirmal','4th',40)

# %%
print(f"INSERT INTO dt2223.student (ID,name,class,age) values({id},{name},{class1},{age})")
# Out:
# INSERT INTO dt2223.student (ID,name,class,age) values(3,nirmal,4th,40)

# %%
mycursor.execute("DROP DATABASE leo")
#delete any database

# %%
mycursor.execute("CREATE TABLE dt2223.student (ID INT(10),name VARCHAR(50), class VARCHAR(50), age INT(10)) ")
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~/Desktop/dummy/venv/lib/python3.10/site-packages/mysql/connector/connection_cext.py:639, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     638         query = query.encode("utf-8")
# --> 639     self._cmysql.query(
#     640         query,
#     641         raw=raw,
#     642         buffered=buffered,
#     643         raw_as_string=raw_as_string,
#     644         query_attrs=self.query_attrs,
#     645     )
#     646 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Table 'student' already exists
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# /Users/nirmalg/Desktop/dummy/SQL.ipynb Cell 9 line 1
# ...

# %%
#mycursor.execute("USE leo")

mycursor.execute("CREATE TABLE dt2223.batch2 (ID INT(4),name VARCHAR(50),att BOOLEAN)")
mydb.commit()

# %%
mycursor.execute("CREATE TABLE batch3 (ID INT(4),name VARCHAR(50),att BOOLEAN)")
mydb.commit()

# %%
mycursor.execute("CREATE TABLE yourtable1 (x INT(8) ZEROFILL)")
#usage of zerofill
#if input of 22 is given output will be 00000022

# %%
mycursor.execute("USE dt2223")

# %%
mycursor.execute("CREATE TABLE dt2223.lucky (salary INT(6),weight DECIMAL(5,3),insurance BOOLEAN)")

#decimal first value is total number of digits(including pre and post decimal digits) and swecond value is for after point
#second value cannot be greater than first value

# %%
#Alter table
#add a new column at first
mycursor.execute("ALTER TABLE lucky ADD covid VARCHAR(5) FIRST")

# %%
#alter table
#add new column after some column name
mycursor.execute("ALTER TABLE lucky ADD covid_status VARCHAR(5) AFTER covid")
mydb.commit()

# %%
#DROP column example
#The ROLLBACK command is the transactional command used to undo transactions that have not already been saved to the database.
mycursor.execute("ALTER TABLE lucky DROP COLUMN covid_status  ")
mydb.rollback()

# %%
#MODIFY(tochange the definition of th column)
mycursor.execute("ALTER TABLE lucky MODIFY covid INT ")

# %%
#rename column
mycursor.execute("ALTER TABLE lucky CHANGE COLUMN covid covidnew INT")

# %%
mycursor.execute("ALTER TABLE dt2223.student RENAME to leo.student")

# %%
#show tables
mycursor.execute("SHOW TABLES FROM dt2223")


for x in mycursor:
  print(x)
# Out:
# ('batch2',)
# ('lucky',)
# ('patien',)
# ('student',)

# %%
#show tables
mycursor.execute("SHOW TABLES IN guvi12")


for x in mycursor:
  print(x)
# Out:
# ('forex',)
# ('lucky',)
# ('test2',)
# ('test_1',)

# %%
#show tables by using where
mycursor.execute("SHOW TABLES IN guvi12 WHERE Tables_in_guvi12= 'forex' ")
for x in mycursor:
  print(x)
# Out:
# ('forex',)

# %%
#truncate(delete all elements without deleting the table structure)
mycursor.execute("TRUNCATE leo.nirmal")
mydb.commit
# Out:
# <bound method MySQLConnection.commit of <mysql.connector.connection.MySQLConnection object at 0x7f027df94f10>>

# %%
mycursor.execute("create table student (id INT,name varchar(50),class varchar(10),age int")

# %%
mycursor.execute("INSERT INTO dt2223.student values(1,'nirmal','2nd',20)")
mydb.commit()


mycursor.execute("INSERT INTO dt2223.student (ID,class,name,age) values(1,'nirmal','2nd',20)")
mydb.commit()

# %%
mycursor.execute("USE dt2223")

# %%
mycursor.execute("CREATE TABLE date123 (datein DATE)")
#mycursor.execute("INSERT INTO date (datein) VALUES ( CURDATE())")

# %%
mycursor.execute("INSERT INTO date123 (datein) VALUES ( CURDATE())")
mycursor.execute("INSERT INTO date123 (datein) VALUES ( CURRENT_DATE())")
mycursor.execute("INSERT INTO date123 (datein) VALUES (CURTIME())")
mycursor.execute("INSERT INTO date123 (datein) VALUES (CURRENT_TIMESTAMP())")
mycursor.execute("INSERT INTO date123 (datein) VALUES (CURRENT_TIME())")
mycursor.execute("INSERT INTO date123 (datein) VALUES (NOW())")
mydb.commit()

#whatever date format given into DATE datatypw will consider in the sameway

# %%
mycursor.execute("CREATE TABLE datestrin (datein VARCHAR(255))")

# %%
mycursor.execute("INSERT INTO datestrin (datein) VALUES ( CURDATE())")
mycursor.execute("INSERT INTO datestrin (datein) VALUES ( CURRENT_DATE())")
mycursor.execute("INSERT INTO datestrin (datein) VALUES (CURTIME())")
mycursor.execute("INSERT INTO datestrin (datein) VALUES (CURRENT_TIMESTAMP())")
mycursor.execute("INSERT INTO datestrin (datein) VALUES (CURRENT_TIME())")
mycursor.execute("INSERT INTO datestrin (datein) VALUES (NOW())")#date and time
mycursor.execute("INSERT INTO datestrin (datein) VALUES (MONTHNAME(NOW()))")
mycursor.execute("INSERT INTO datestrin (datein) VALUES (DAYNAME(NOW()))")
mycursor.execute("INSERT INTO datestrin (datein) VALUES (HOUR(NOW()))")
mycursor.execute("INSERT INTO datestrin (datein) VALUES (MINUTE(NOW()))")
mycursor.execute("INSERT INTO datestrin (datein) VALUES (DATE_ADD(NOW(),INTERVAL -10 DAY))")
mycursor.execute("INSERT INTO datestrin (datein) VALUES (DATE_FORMAT(NOW(),'%W %D %M %Y %T %H'))")
mycursor.execute("INSERT INTO datestrin (datein) VALUES (UTC_DATE())")#UTC_TIME,UTC_TIMESTAMP
mydb.commit()

# %%
mycursor.execute("CREATE TABLE blobtest1 (datein BLOB NOT NULL)")

# %%
# Convert images or files data to binary format
def convert_data(file_name):
    with open(file_name, 'rb') as file:
        binary_data = file.read()
    return binary_data
a=convert_data("/Users/nirmalg/Desktop/unnamed.png")
#print(a)

query="""INSERT INTO blobtest1 (datein) VALUES (%s)"""
mycursor.execute(query,[a])
mydb.commit()

# %%
import mysql.connector


# Convert images or files data to binary format
def convert(file_name):
    with open(file_name, 'rb') as file:
        binary_data = file.read()
    return binary_data


try:
    connection = mysql.connector.connect(host='localhost',
                                         database='guvi12',
                                         user='root',
                                         password='')
    mycursor = connection.cursor()
    # create table query
    create_table = """CREATE TABLE blob11111( name VARCHAR (255) NOT NULL, profile_pic BLOB NOT NULL, \
    imp_files BLOB NOT NULL) """

    # Execute the create_table query first
    mycursor.execute(create_table)
    # printing successful message
    print("Table created Successfully")

    query = """ INSERT INTO blob11111( name, profile_pic, imp_files)VALUES ( %s,%s,%s)"""

    # First Data Insertion
    name = "nethaji"
    picture = convert_data("/home/linux/Desktop/logo.png")
    text_file = convert_data('/home/linux/Desktop/Android.pdf')

    # Inserting the data in database in tuple format
    result = mycursor.execute(
        query, (name, picture, text_file))
    # Committing the data
    connection.commit()
    print("Successfully Inserted Values")

# Print error if occured
except mysql.connector.Error as error:
    print(format(error))

finally:

    # Closing all resources
    if connection.is_connected():

        mycursor.close()
        connection.close()
        print("MySQL connection is closed")
# Out:
# Table created Successfully
# Successfully Inserted Values
# MySQL connection is closed

# %% [markdown]
# #select and view

# %%
mycursor.execute("USE leo")

# %%
mydb.commit()

# %%
# !pip install tabulate
# Out:
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
mycursor.execute("SELECT * FROM dt2223.diabetes")


out=mycursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +---------------+-----------+-----------------+-----------------+-----------+-------+----------------------------+-------+-----------+
# |   Pregnancies |   Glucose |   BloodPressure |   SkinThickness |   Insulin |   BMI |   DiabetesPedigreeFunction |   Age |   Outcome |
# |---------------+-----------+-----------------+-----------------+-----------+-------+----------------------------+-------+-----------|
# |             6 |       148 |              72 |              35 |         0 |  33.6 |                      0.627 |    50 |         1 |
# |             1 |        85 |              66 |              29 |         0 |  26.6 |                      0.351 |    31 |         0 |
# |             8 |       183 |              64 |               0 |         0 |  23.3 |                      0.672 |    32 |         1 |
# |             1 |        89 |              66 |              23 |        94 |  28.1 |                      0.167 |    21 |         0 |
# ...

# %%
mycursor.execute("SELECT * FROM dt2223.diabetes")

mycursor.execute("select age, bmi from diabetes")

mycursor.execute("select age, bmi from diabetes limit 5")

mycursor.execute("select age, bmi, outcome from diabetes where outcome=1")

mycursor.execute("select bloodpressure from diabetes where outcome=1 and age<30")

mycursor.execute("select bloodpressure as guviBP from diabetes where outcome=1 and age<30")

mycursor.execute("select bmi, age from diabetes where age = 20 or age =30")

mycursor.execute("select bmi, age from diabetes where age in (30,31,32,33) ")

mycursor.execute("select bmi from diabetes where age >19 and age <31")

mycursor.execute("select bmi from diabetes where age between 20 and 30")

mycursor.execute("select BMI+AGE as BMage from diabetes")

mycursor.execute("select age, bmi from diabetes where age not in (30,31,32,33)")

#mycursor.execute("select ")


mycursor.execute("WITH nethaji as (SELECT age,bmi from diabetes where age<30)select age,bmi from nethaji where age>19")


mycursor.execute("SELECT COUNT(outcome) from diabetes where age>60 and outcome=1 ")

mycursor.execute("SELECT MAX(AGE) as oldest ,MIN(AGE) as youngest from diabetes")

mycursor.execute("SELECT MAX(pregnancies) as highest ,MIN(pregnancies) as lowest from diabetes")

mycursor.execute("select sum(age)/count(age) as average_age from diabetes where outcome=1")

mycursor.execute("select AVG(age) as average_age from diabetes where outcome=1")



mycursor.execute("SELECT * FROM diabetes where glucose >(SELECT AVG(glucose) from diabetes)")

mycursor.execute("SELECT * FROM diabetes where age in(select age from yy)")

mycursor.execute("select age,outcome,pregnancies from diabetes where outcome=1 and pregnancies<5 ORDER BY age DESC")


mycursor.execute("select age,bmi,outcome from diabetes order by age ASC")



out=mycursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +-------+-----------+---------------+
# |   age |   outcome |   pregnancies |
# |-------+-----------+---------------|
# |    70 |         1 |             4 |
# |    67 |         1 |             4 |
# |    66 |         1 |             2 |
# |    62 |         1 |             2 |
# |    62 |         1 |             0 |
# |    61 |         1 |             4 |
# |    60 |         1 |             4 |
# |    59 |         1 |             1 |
# |    56 |         1 |             4 |
# |    53 |         1 |             2 |
# |    52 |         1 |             0 |
# |    52 |         1 |             3 |
# |    52 |         1 |             1 |
# |    52 |         1 |             2 |
# |    47 |         1 |             1 |
# |    46 |         1 |             4 |
# |    46 |         1 |             1 |
# |    45 |         1 |             1 |
# |    45 |         1 |             4 |
# |    44 |         1 |             3 |
# |    43 |         1 |             1 |
# |    42 |         1 |             1 |
# ...

# %%
mycursor.execute("SHOW COLUMNS FROM diabetes")

out=mycursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +--------------------------+--------------+--------+-------+-----------+---------+
# | Field                    | Type         | Null   | Key   | Default   | Extra   |
# |--------------------------+--------------+--------+-------+-----------+---------|
# | Pregnancies              | int(2)       | YES    |       |           |         |
# | Glucose                  | int(3)       | YES    |       |           |         |
# | BloodPressure            | int(3)       | YES    |       |           |         |
# | SkinThickness            | int(2)       | YES    |       |           |         |
# | Insulin                  | int(3)       | YES    |       |           |         |
# | BMI                      | decimal(3,1) | YES    |       |           |         |
# | DiabetesPedigreeFunction | decimal(4,3) | YES    |       |           |         |
# | Age                      | int(2)       | YES    |       |           |         |
# ...

# %%
# !pip install tabulate
# Out:
# ...
#   Using cached tabulate-0.9.0-py3-none-any.whl.metadata (34 kB)
# Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# ...
#
# [notice] A new release of pip is available: 23.3 -> 24.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
#mycursor.execute("SELECT * FROM diabetes ")

#mycursor.execute("SELECT * FROM diabetes WHERE outcome=1 ")

#mycursor.execute("select age,bmi,outcome from diabetes limit 10 ")

# mycursor.execute("select age,outcome,pregnancies from diabetes where outcome=1 and pregnancies<5 ORDER BY age DESC")


# mycursor.execute("select age,bmi,outcome from diabetes order by age ASC")

# mycursor.execute("select age,bmi from diabetes WHERE NOT outcome=1")

# mycursor.execute("select * from diabetes where age in(10,20,30)")

# mycursor.execute("select * from diabetes where (age < 40 and  bmi >28)")

# mycursor.execute("select (glucose/insulin) as guvi from diabetes order by guvi DESC ")


# mycursor.execute("select count(Pregnancies) from diabetes where Pregnancies =1")


# mycursor.execute("select (sum(Age)/count(age)) from diabetes where outcome=1")

# mycursor.execute("select AVG(age) as average_num from diabetes where outcome=1")

# mycursor.execute("select avg(age) from diabetes where insulin between 100 and 120")

# mycursor.execute("select min(age) from diabetes where insulin between 100 and 120")

# mycursor.execute("select max(age) from diabetes where insulin between 100 and 120")


#mycursor.execute("select avg(Age) from diab where outcome = 1 and Pregnancies = 2 ")


mycursor.execute("USE dt2223")
mycursor.execute("select count(*) from diabetes where  outcome = 0  and bloodpressure in \
    ( select bloodpressure from diabetes where bloodpressure > 40 and bloodpressure < 91 )")


#mycursor.execute("SELECT * FROM diabetes where glucose >(SELECT AVG(glucose) from diabetes)")

#mycursor.execute("SELECT Insulin,BMI,Age FROM diabetes")
#mycursor.execute("SELECT count( * ) as total_record FROM diabetes")
out=mycursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +---------------+-----------+-----------------+-----------------+-----------+-------+----------------------------+-------+-----------+
# |   Pregnancies |   Glucose |   BloodPressure |   SkinThickness |   Insulin |   BMI |   DiabetesPedigreeFunction |   Age |   Outcome |
# |---------------+-----------+-----------------+-----------------+-----------+-------+----------------------------+-------+-----------|
# |             6 |       148 |              72 |              35 |         0 |  33.6 |                      0.627 |    50 |         1 |
# |             8 |       183 |              64 |               0 |         0 |  23.3 |                      0.672 |    32 |         1 |
# |             0 |       137 |              40 |              35 |       168 |  43.1 |                      2.288 |    33 |         1 |
# |             2 |       197 |              70 |              45 |       543 |  30.5 |                      0.158 |    53 |         1 |
# ...

# %%
print(True or True and True)
# Out:
# True

# %%
mycursor.execute("select count(*) from diabetes where age>40 and pregnancies in \
                 (select pregnancies from diabetes where pregnancies between 2 and 7 ) \
                 and glucose in(select glucose from diabetes where glucose between 140 and 180) and outcome=0")
out=mycursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +------------+
# |   count(*) |
# |------------|
# |          9 |
# +------------+

# %%
mycursor.execute("SELECT * FROM diabetes WHERE Pregnancies=1 ORDER BY BMI DESC,insulin ASC")

out=mycursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +---------------+-----------+-----------------+-----------------+-----------+-------+----------------------------+-------+-----------+
# |   Pregnancies |   Glucose |   BloodPressure |   SkinThickness |   Insulin |   BMI |   DiabetesPedigreeFunction |   Age |   Outcome |
# |---------------+-----------+-----------------+-----------------+-----------+-------+----------------------------+-------+-----------|
# |             1 |        88 |              30 |              42 |        99 |  55   |                      0.496 |    26 |         1 |
# |             1 |       122 |              90 |              51 |       220 |  49.7 |                      0.325 |    31 |         1 |
# |             1 |       147 |              94 |              41 |         0 |  49.3 |                      0.358 |    27 |         1 |
# |             1 |       144 |              82 |              46 |       180 |  46.1 |                      0.335 |    46 |         1 |
# ...

# %%
#mycursor.execute("SELECT * FROM diabetes GROUP BY Pregnancies ")
#for x in mycursor:
# print(x)
#mycursor.execute("SELECT pregnancies,count(*),AVG(age) FROM diabetes GROUP BY pregnancies ")


mycursor.execute("SELECT outcome,MIN(insulin) as minins ,MAX(insulin) as maxins from diabetes group by outcome")

# #mycursor.execute("SELECT pregnancies,avg(age) FROM diabetes GROUP BY pregnancies ")

mycursor.execute("SELECT CASE \
         WHEN bmi < 18.5 THEN 'Underweight' \
         WHEN bmi BETWEEN 18.5 AND 24.9 THEN 'Normal' \
         WHEN bmi BETWEEN 25 AND 29.9 THEN 'Overweight' \
         ELSE 'Obese' \
       END \
      AS bmi_category, \
    COUNT(*) AS patient_count \
FROM diabetes \
GROUP BY bmi_category")

out=mycursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in mycursor.description],showindex="always",  tablefmt='psql'))
# Out:
# +----+----------------+-----------------+
# |    | bmi_category   |   patient_count |
# |----+----------------+-----------------|
# |  0 | Normal         |               7 |
# |  1 | Obese          |             219 |
# |  2 | Overweight     |              40 |
# |  3 | Underweight    |             502 |
# +----+----------------+-----------------+

# %%
mycursor.execute("""
    SELECT Age, Pregnancies, COUNT(*) OVER (PARTITION BY Pregnancies ORDER BY Age DESC) as Countw
    FROM diabetes 
""")
out=mycursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +-------+---------------+----------+
# |   Age |   Pregnancies |   Countw |
# |-------+---------------+----------|
# |    67 |             0 |        1 |
# |    65 |             0 |        2 |
# |    62 |             0 |        3 |
# |    59 |             0 |        4 |
# |    58 |             0 |        5 |
# |    52 |             0 |        6 |
# |    46 |             0 |        8 |
# |    46 |             0 |        8 |
# |    44 |             0 |       10 |
# |    44 |             0 |       10 |
# |    41 |             0 |       11 |
# |    38 |             0 |       12 |
# |    36 |             0 |       13 |
# |    35 |             0 |       15 |
# |    35 |             0 |       15 |
# |    33 |             0 |       17 |
# |    33 |             0 |       17 |
# |    32 |             0 |       19 |
# |    32 |             0 |       19 |
# |    31 |             0 |       23 |
# |    31 |             0 |       23 |
# |    31 |             0 |       23 |
# ...

# %%
mycursor.execute("""
    SELECT Age, Pregnancies, AVG(age) OVER (PARTITION BY Pregnancies ORDER BY Age DESC) as Countw
    FROM diabetes
""")
out=mycursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +-------+---------------+----------+
# |   Age |   Pregnancies |   Countw |
# |-------+---------------+----------|
# |    67 |             0 |  67      |
# |    65 |             0 |  66      |
# |    62 |             0 |  64.6667 |
# |    59 |             0 |  63.25   |
# |    58 |             0 |  62.2    |
# |    52 |             0 |  60.5    |
# |    46 |             0 |  56.875  |
# |    46 |             0 |  56.875  |
# |    44 |             0 |  54.3    |
# |    44 |             0 |  54.3    |
# |    41 |             0 |  53.0909 |
# |    38 |             0 |  51.8333 |
# |    36 |             0 |  50.6154 |
# |    35 |             0 |  48.5333 |
# |    35 |             0 |  48.5333 |
# |    33 |             0 |  46.7059 |
# |    33 |             0 |  46.7059 |
# |    32 |             0 |  45.1579 |
# |    32 |             0 |  45.1579 |
# |    31 |             0 |  42.6957 |
# |    31 |             0 |  42.6957 |
# |    31 |             0 |  42.6957 |
# ...

# %%
mycursor.execute("""
    SELECT Age, Pregnancies, BloodPressure, 
           RANK() OVER (PARTITION BY Pregnancies ORDER BY BloodPressure DESC) as Rank
    FROM diabetes
""")
out=mycursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +-------+---------------+-----------------+--------+
# |   Age |   Pregnancies |   BloodPressure |   Rank |
# |-------+---------------+-----------------+--------|
# |    26 |             0 |             110 |      1 |
# |    41 |             0 |             104 |      2 |
# |    35 |             0 |             100 |      3 |
# |    21 |             0 |              96 |      4 |
# |    26 |             0 |              94 |      5 |
# |    23 |             0 |              90 |      6 |
# |    23 |             0 |              90 |      6 |
# |    46 |             0 |              90 |      6 |
# |    21 |             0 |              90 |      6 |
# |    35 |             0 |              90 |      6 |
# |    29 |             0 |              88 |     11 |
# |    38 |             0 |              88 |     11 |
# |    21 |             0 |              88 |     11 |
# |    31 |             0 |              88 |     11 |
# |    32 |             0 |              88 |     11 |
# ...

# %%
mycursor.execute("""
    SELECT Age, Pregnancies, BloodPressure, 
           RANK() OVER ( ORDER BY BloodPressure DESC) as Rank
    FROM diab
""")
out=mycursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +-------+---------------+-----------------+--------+
# |   Age |   Pregnancies |   BloodPressure |   Rank |
# |-------+---------------+-----------------+--------|
# |    27 |             1 |             122 |      1 |
# |    44 |            13 |             114 |      2 |
# |    54 |             9 |             110 |      3 |
# |    37 |             4 |             110 |      3 |
# |    26 |             0 |             110 |      3 |
# |    37 |             5 |             108 |      6 |
# |    65 |             5 |             108 |      6 |
# |    47 |            10 |             106 |      8 |
# |    43 |             8 |             106 |      8 |
# |    51 |            11 |             106 |      8 |
# |    41 |             0 |             104 |     11 |
# |    52 |             5 |             104 |     11 |
# |    45 |             1 |             102 |     13 |
# |    22 |             3 |             100 |     14 |
# |    45 |             8 |             100 |     14 |
# ...

# %%
mycursor.execute("""
    SELECT Age, Pregnancies, BloodPressure, 
        DENSE_RANK() OVER (PARTITION BY Pregnancies ORDER BY BloodPressure DESC) as DenseRank
    FROM diabetes
""")

out=mycursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +-------+---------------+-----------------+-------------+
# |   Age |   Pregnancies |   BloodPressure |   DenseRank |
# |-------+---------------+-----------------+-------------|
# |    26 |             0 |             110 |           1 |
# |    41 |             0 |             104 |           2 |
# |    35 |             0 |             100 |           3 |
# |    21 |             0 |              96 |           4 |
# |    26 |             0 |              94 |           5 |
# |    23 |             0 |              90 |           6 |
# |    23 |             0 |              90 |           6 |
# |    46 |             0 |              90 |           6 |
# |    21 |             0 |              90 |           6 |
# |    35 |             0 |              90 |           6 |
# |    29 |             0 |              88 |           7 |
# |    38 |             0 |              88 |           7 |
# |    21 |             0 |              88 |           7 |
# ...

# %% [markdown]
# # constraints

# %% [markdown]
# # Constraints
# NOT NULL - Ensures that a column cannot have a NULL value
#
# UNIQUE - Ensures that all values in a column are different
#
# PRIMARY KEY - A combination of a NOT NULL and UNIQUE. Uniquely identifies each row in a table
#
# FOREIGN KEY - Prevents actions that would destroy links between tables
#
# CHECK - Ensures that the values in a column satisfies a specific condition
#
# DEFAULT - Sets a default value for a column if no value is specified
#
# CREATE INDEX - Used to create and retrieve data from the database very quickly

# %%
#NOT NULL
mycursor.execute("CREATE TABLE stu1 (no INTEGER,name TEXT NOT NULL,school VARCHAR(20)) ")

# mycursor.execute("CREATE TABLE leo.test (ID INT(6) UNIQUE)")

# mycursor.execute("CREATE TABLE leo.abc (name varchar(50) NOT NULL,age int(3) NOT NULL)")

# mycursor.execute("CREATE TABLE leo.abcd (name varchar(50) NOT NULL,age int(3) )")

# %%
a=input("enter no")
b=input("enter name")
c=input("emter school")
query="INSERT INTO dt2223.stu1 (no,name,school) VALUES (%s,%s,%s)"
mycursor.execute(query,(a,None,c))
mydb.commit()
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~/Desktop/GUVI/MDTM20/venv/lib/python3.10/site-packages/mysql/connector/connection_cext.py:705, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     704         query = query.encode("utf-8")
# --> 705     self._cmysql.query(
#     706         query,
#     707         raw=raw,
#     708         buffered=buffered,
#     709         raw_as_string=raw_as_string,
#     710         query_attrs=self.query_attrs,
#     711     )
#     712 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Column 'name' cannot be null
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# Cell In[28], line 5
#       3 c=input("emter school")
#       4 query="INSERT INTO dt2223.stu1 (no,name,school) VALUES (%s,%s,%s)"
# ...

# %%
print("INSERT INTO leo.abcd (name,age) VALUES (%s,%s)"%(1,2))
print("INSERT INTO leo.abcd (name,age) VALUES ({name},{age})".format(name="nirmal",age=12))
name="nirmal"
age=12
print(f"INSERT INTO leo.abcd (name,age) VALUES ({name},{age})")
# Out:
# INSERT INTO leo.abcd (name,age) VALUES (1,2)
# INSERT INTO leo.abcd (name,age) VALUES (nirmal,12)
# INSERT INTO leo.abcd (name,age) VALUES (nirmal,12)

# %%
mycursor.execute("INSERT INTO leo.test VALUES(123)")
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~/Desktop/dummy/venv/lib/python3.10/site-packages/mysql/connector/connection_cext.py:639, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     638         query = query.encode("utf-8")
# --> 639     self._cmysql.query(
#     640         query,
#     641         raw=raw,
#     642         buffered=buffered,
#     643         raw_as_string=raw_as_string,
#     644         query_attrs=self.query_attrs,
#     645     )
#     646 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Duplicate entry '123' for key 'ID'
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# /Users/nirmalg/Desktop/dummy/SQL.ipynb Cell 59 line 1
# ...

# %%
a=input()
b=input()
c=input()
query="INSERT INTO stu1 (no,name,school) VALUES (%s,%s,%s)"
mycursor.execute(query,(a,None,c))
mydb.commit()
# Out:
# 12
# guvi
# guvi
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/mysql/connector/connection_cext.py:611, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     610         query = query.encode("utf-8")
# --> 611     self._cmysql.query(
#     612         query,
#     613         raw=raw,
#     614         buffered=buffered,
#     615         raw_as_string=raw_as_string,
#     616         query_attrs=self._query_attrs,
#     617     )
#     618 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Column 'name' cannot be null
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# Cell In[42], line 5
#       3 c=input()
# ...

# %%
#unique and check
mycursor.execute("CREATE TABLE u (no INTEGER,name TEXT UNIQUE,school VARCHAR(20),age INT CHECK(age<18)) ")

# %%
a=input()
b=input()
c=input()
d=input()
query="INSERT INTO u (no,name,school,age) VALUES (%s,%s,%s,%s)"
mycursor.execute(query,(a,b,c,d))
mydb.commit()
#duplicate entry error
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File ~/Desktop/dummy/venv/lib/python3.10/site-packages/mysql/connector/connection_cext.py:639, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     638         query = query.encode("utf-8")
# --> 639     self._cmysql.query(
#     640         query,
#     641         raw=raw,
#     642         buffered=buffered,
#     643         raw_as_string=raw_as_string,
#     644         query_attrs=self.query_attrs,
#     645     )
#     646 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: CONSTRAINT `u.age` failed for `leo`.`u`
#
# The above exception was the direct cause of the following exception:
#
# IntegrityError                            Traceback (most recent call last)
# /Users/nirmalg/Desktop/dummy/SQL.ipynb Cell 64 line 6
# ...

# %%
#creating an index which is not visible
mycursor.execute("CREATE INDEX user_id ON test2 (accno, name)")
# Out:
# ---------------------------------------------------------------------------
# MySQLInterfaceError                       Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/mysql/connector/connection_cext.py:611, in CMySQLConnection.cmd_query(self, query, raw, buffered, raw_as_string)
#     610         query = query.encode("utf-8")
# --> 611     self._cmysql.query(
#     612         query,
#     613         raw=raw,
#     614         buffered=buffered,
#     615         raw_as_string=raw_as_string,
#     616         query_attrs=self._query_attrs,
#     617     )
#     618 except MySQLInterfaceError as err:
#
# MySQLInterfaceError: Table 'dt1819.test2' doesn't exist
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[48], line 2
#       1 #creating an index which is not visible
# ...

# %%
mycursor.execute("SHOW INDEXES FROM u ")
out=mycursor.fetchall()
print(out)
from tabulate import tabulate
print(tabulate(out, tablefmt='psql'))
# Out:
# [('u', 0, 'name', 1, 'name', 'A', None, None, None, 'YES', 'HASH', '', '')]
# +---+---+------+---+------+---+--+--+--+-----+------+--+--+
# | u | 0 | name | 1 | name | A |  |  |  | YES | HASH |  |  |
# +---+---+------+---+------+---+--+--+--+-----+------+--+--+

# %%
mydb.commit()

# %%
mycursor.execute("DELETE FROM leo.abcd where name='nirmal'")
mydb.commit()

# %%
mycursor.execute("UPDATE leo.abcd SET name='guvi' where name='nirmal'")
mydb.commit()

# %% [markdown]
# # PRIMARY KEY
# Constraint
# This constraint is used to identify each record in a table uniquely. If the column contains primary key constraints, then it cannot be null or empty. A table may have duplicate columns, but it can contain only one primary key. It always contains unique value into a column
#
# #Foreign Key Constraint
# This constraint is used to link two tables together. It is also known as the referencing key. A foreign key column matches the primary key field of another table. It means a foreign key field in one table refers to the primary key field of another table
#
#
# A FOREIGN KEY constraint does not have to be linked only to a PRIMARY KEY constraint in another table; it can also be defined to reference the columns of a UNIQUE constraint in another table.

# %%
mycursor.execute("USE DT2223")

# %%
mycursor.execute("CREATE TABLE aadhardetails (name VARCHAR(30),ADDRESS VARCHAR(20),AADHARID INTEGER PRIMARY KEY)")

# %%
mycursor.execute("INSERT INTO aadhardetails (name,address,aadharid) VALUES('nethaji','coimbatore',12345678)")
mydb.commit()

# %%
mydb.commit()

# %%
mycursor.execute("CREATE TABLE bankacc(name VARCHAR(20),type VARCHAR(2),accno INT PRIMARY KEY,aadhar INT ,FOREIGN KEY (aadhar)REFERENCES aadhardetails(aadharid))")

# %%
mycursor.execute("INSERT INTO bankacc (name,type,accno,aadhar) VALUES('nethaji','Rd',124455,12345678)")

# %%
mydb.commit()

# %%
mycursor.execute("CREATE TABLE pancard(name VARCHAR(20),dob INT,panid VARCHAR(16),aadhar INT ,FOREIGN KEY(aadhar) REFERENCES aadhardetails(aadharid),PRIMARY KEY(panid))")

# %%
mycursor.execute("INSERT INTO pancard(name,dob,panid,aadhar) VALUES('nethaji',123,'BABPN78',12345678)")

# %%
mydb.commit()

# %%
# !pip3 install tabulate

# %%
mycursor.execute("DESCRIBE test")
out=mycursor.fetchall()
print(out)
from tabulate import tabulate
print(tabulate(out, headers=['accno', 'name','empdomain','age'], tablefmt='psql'))
# Out:
# [('accno', 'int(11)', 'NO', 'PRI', None, ''), ('name', 'text', 'YES', '', None, ''), ('empdoamin', 'varchar(20)', 'YES', '', None, ''), ('age', 'int(11)', 'YES', '', None, '')]
# +-----------+-------------+---------+--------+-------------+-------+
# |           |             | accno   | name   | empdomain   | age   |
# |-----------+-------------+---------+--------+-------------+-------|
# | accno     | int(11)     | NO      | PRI    |             |       |
# | name      | text        | YES     |        |             |       |
# | empdoamin | varchar(20) | YES     |        |             |       |
# | age       | int(11)     | YES     |        |             |       |
# +-----------+-------------+---------+--------+-------------+-------+

# %% [markdown]
# # Partitions
# latest mysql doesnt support vertical partioning
#
# partitions can be enablesd and disables

# %%
mycursor.execute("SET @@global.sql_mode= ''")

# %%
# use football databse
#to import big files change conf file as follows
#SET @@global.sql_mode= '';    ----exec command

#set global net_buffer_length=1000000;
#set global max_allowed_packet=1000000000;
mycursor.execute("CREATE TABLE crypto(timestamp INT,open DOUBLE ,close INT,high DOUBLE,low DOUBLE,volume DOUBLE)")

# %%
#by default we have varchar from dataset and it should bechanged to int for this operation
mycursor.execute(" ALTER TABLE forex\
PARTITION BY RANGE (close) (\
      partition p0 VALUES LESS THAN (10000),\
      partition p1 VALUES LESS THAN (20000),\
      partition p2 VALUES LESS THAN (30000),\
      partition p3 VALUES LESS THAN (40000),\
      partition p4 VALUES LESS THAN (50000),\
      partition p5 VALUES LESS THAN (60000),\
      partition p6 VALUES LESS THAN  MAXVALUE\
  )")
mydb.commit()

# %%
#lets check
mycursor.execute("SELECT * FROM information_schema.partitions WHERE TABLE_SCHEMA='guvi1' ")
out=mycursor.fetchall()
print(out)
from tabulate import tabulate
print(tabulate(out,  tablefmt='psql'))
# Out:
# [('def', 'guvi1', 'aadhardetails', None, None, None, None, None, None, None, None, None, 2, 8192, 16384, None, 0, 0, datetime.datetime(2022, 1, 21, 11, 44, 33), None, None, None, '', '', None), ('def', 'guvi1', 'bankacc', None, None, None, None, None, None, None, None, None, 2, 8192, 16384, None, 16384, 0, datetime.datetime(2022, 1, 21, 11, 52, 4), None, None, None, '', '', None), ('def', 'guvi1', 'blobtest1', None, None, None, None, None, None, None, None, None, 0, 0, 16384, None, 0, 0, datetime.datetime(2022, 1, 20, 11, 42, 15), None, None, None, '', '', None), ('def', 'guvi1', 'cons', None, None, None, None, None, None, None, None, None, 0, 0, 16384, None, 0, 0, datetime.datetime(2022, 1, 20, 10, 44, 6), None, None, None, '', '', None), ('def', 'guvi1', 'date', None, None, None, None, None, None, None, None, None, 7, 2340, 16384, None, 0, 0, datetime.datetime(2022, 1, 12, 0, 50, 57), datetime.datetime(2022, 1, 24, 8, 27, 6), None, None, '', '', None), ('def', 'guvi1', 'date1', Non
# ...

# %%
#check also with wrong linits eg:35000 and 38000-->will return empty

mycursor.execute(" SELECT * FROM forex PARTITION (p1) WHERE close BETWEEN 10000 and 11000")
out=mycursor.fetchall()
print("Total number of rows in table: ", mycursor.rowcount)
print(out)
from tabulate import tabulate
print(tabulate(out, tablefmt='psql'))

# %% [markdown]
# # joins

# %%
#to import using python need to create table with all column names
#mycursor.execute("LOAD DATA INFILE '/home/linux/Desktop/pima-indians-diabetes.data.csv' INTO TABLE test2")
#mydb.commit()

# %%
mycursor.execute("CREATE TABLE students(ID INT PRIMARY KEY,NAME VARCHAR(20),PH INT) ")

# %%
mycursor.execute("INSERT INTO students (ID,NAME,PH) VALUES(1,'nethaji',12345)")

# %%
mycursor.execute("INSERT INTO students (ID,NAME,PH) VALUES(2,'nirmal',123456)")

# %%
mydb.commit()

# %%
mycursor.execute("CREATE TABLE marks(ID INT ,maths int,phy INT,chem INT) ")
mydb.commit()

# %%
mycursor.execute("INSERT INTO marks (ID,maths,phy,chem) VALUES(4,99,85,50)")
mydb.commit()

# %%
#INNER JOIN

mycursor.execute("SELECT students.ID,students.name,marks.maths,marks.phy \
FROM students \
RIGHT JOIN marks ON students.ID = marks.ID")

out=mycursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +------+---------+---------+-------+
# |   ID | name    |   maths |   phy |
# |------+---------+---------+-------|
# |    1 | nethaji |      91 |    80 |
# |    2 | nirmal  |      91 |    80 |
# |    3 |         |      91 |    80 |
# |    4 |         |      99 |    85 |
# +------+---------+---------+-------+

# %%
mydb.commit()

# %%
mycursor.execute("CREATE TABLE sports (ID INT PRIMARY KEY,100mts INT,football INT,chess INT) ")

# %%
mycursor.execute("INSERT INTO sports (ID,100mts,football,chess) VALUES(1,10,8,10)")
mydb.commit()

# %%
#joining columns from 3 different tables
mycursor.execute("SELECT students.ID, marks.maths,marks.chem,marks.phy,sports.100mts,sports.football \
FROM students \
INNER JOIN marks ON students.ID = marks.ID \
INNER JOIN sports ON students.ID = sports.id ")

out=mycursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +------+---------+--------+-------+----------+------------+
# |   ID |   maths |   chem |   phy |   100mts |   football |
# |------+---------+--------+-------+----------+------------|
# |    1 |      91 |     50 |    80 |       10 |          8 |
# +------+---------+--------+-------+----------+------------+

# %%
#left join :eturns all rows from the left table, even if there are no matches in the right table
mycursor.execute("SELECT students.ID, marks.maths,marks.chem,marks.phy \
FROM students \
RIGHT JOIN marks ON students.ID = marks.ID")

out=mycursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +------+---------+--------+-------+
# |   ID |   maths |   chem |   phy |
# |------+---------+--------+-------|
# |    2 |      99 |     50 |    80 |
# |    1 |      99 |     50 |    80 |
# |      |      25 |     45 |    35 |
# +------+---------+--------+-------+

# %%
mydb.commit()

# %%
#RIGHT JOIN: returns all rows from the right table, even if there are no matches in the left table.

mycursor.execute("SELECT students.ID, marks.maths,marks.chem,marks.phy \
FROM students \
RIGHT JOIN marks ON students.ID = marks.ID")

out=mycursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))
# Out:
# +------+---------+--------+-------+
# |   ID |   maths |   chem |   phy |
# |------+---------+--------+-------|
# |    2 |      99 |     50 |    80 |
# |    1 |      99 |     50 |    80 |
# |      |      25 |     45 |    35 |
# +------+---------+--------+-------+

# %%
mydb.commit()

# %%
#FULL JOIN gets all records from both tables and puts NULL in the columns where related records do not exist in the opposite table

mycursor.execute("SELECT marks.id,marks.maths,marks.chem,marks.phy \
FROM students \
FULL JOIN marks on  ")

out=mycursor.fetchall()
from tabulate import tabulate
print(tabulate(out,headers=[i[0] for i in mycursor.description],  tablefmt='psql'))

# %% [markdown]
# #Triggers
# A trigger is called a special procedure because it cannot be called directly like a stored procedure
#
# Row-Level Trigger: It is a trigger, which is activated for each row by a triggering statement such as insert, update, or delete. For example, if a table has inserted, updated, or deleted multiple rows, the row trigger is fired automatically for each row affected by the insert, update, or delete statement.

# %%
#(BEFOR | AFTER) table_name (INSERT | UPDATE | DELETE)

mycursor.execute("CREATE TABLE employee(  \
    name varchar(45) NOT NULL,   \
    occupation varchar(35) NOT NULL,  working_date date, working_hours varchar(10)\
)  ")

# %%
mycursor.execute("INSERT INTO employee VALUES
('nethaji', 'Scientist', '2020-10-04', 12),
('sandeep', 'Engineer', '2020-10-04', 10),
('bharath', 'Actor', '2020-10-04', 13),
('sailakshmi', 'Doctor', '2020-10-04', 14),
('hariganesh', 'Teacher', '2020-10-04', 12),
('tarun', 'Business', '2020-10-04', 11)  ")

# %%
#creating trigger
mycursor.execute("DELIMITER// CREATE TRIGGER before_insert_empworkinghrs  \
BEFORE INSERT ON employee FOR EACH ROW \
BEGIN \
IF (NEW.working_hours < 0) THEN SET NEW.working_hours = 0; \
END IF;\
END// \
DELIMITER")

# %%
import pandas as pd
import numpy as np

# Generate a sample schema with 100 rows of data
num_rows = 100
data = {
    'id': np.arange(1, num_rows + 1),
    'name': [f'name_{i}' for i in range(1, num_rows + 1)],
    'date': pd.date_range(start='2023-01-01', periods=num_rows, freq='D'),
    'amount': np.random.uniform(low=10.0, high=100.0, size=num_rows)
}

# Create a DataFrame
df = pd.DataFrame(data)

# Create 5 different CSV files with the same schema but different data
file_names = []
for i in range(1, 6):
    df_sample = df.copy()
    df_sample['id'] = df_sample['id'] + (i * num_rows)
    df_sample['name'] = df_sample['name'].apply(lambda x: f'{x}_file{i}')
    file_name = f'data_file_{i}.csv'
    df_sample.to_csv(file_name, index=False)
    file_names.append(file_name)

file_names
# Out:
# ['data_file_1.csv',
#  'data_file_2.csv',
#  'data_file_3.csv',
#  'data_file_4.csv',
#  'data_file_5.csv']
